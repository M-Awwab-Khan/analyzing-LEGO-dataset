# %% [markdown]
# # Introduction
#
# Today we'll dive deep into a dataset all about LEGO. From the dataset we can ask whole bunch of interesting questions about the history of the LEGO company, their product offering, and which LEGO set ultimately rules them all:
#
# <ul type="square">
# <li>What is the most enormous LEGO set ever created and how many parts did it have?</li>
#
# <li>How did the LEGO company start out? In which year were the first LEGO sets released and how many sets did the company sell when it first launched?</li>
#
# <li>Which LEGO theme has the most sets? Is it one of LEGO's own themes like Ninjago or a theme they licensed liked Harry Potter or Marvel Superheroes?</li>
#
# <li>When did the LEGO company really expand its product offering? Can we spot a change in the company strategy based on how many themes and sets did it released year-on-year?</li>
#
# <li>Did LEGO sets grow in size and complexity over time? Do older LEGO
# sets tend to have more or fewer parts than newer sets?</li>
# </ul>
#
# **Data Source**
#
# [Rebrickable](https://rebrickable.com/downloads/) has compiled data on all the LEGO pieces in existence. I recommend you use download the .csv files provided in this lesson.

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data Exploration

# %% [markdown]
# **Challenge**: How many different colours does the LEGO company produce? Read the colors.csv file in the data folder and find the total number of unique colours. Try using the [.nunique() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nunique.html?highlight=nunique#pandas.DataFrame.nunique) to accomplish this.

# %%
colors = pd.read_csv('data/colors.csv')

# %%
colors.head()
# Out:
#    id            name     rgb is_trans
# 0  -1       [Unknown]  0033B2        f
# 1   0           Black  05131D        f
# 2   1            Blue  0055BF        f
# 3   2           Green  237841        f
# 4   3  Dark Turquoise  008F9B        f

# %%
colors.shape
# Out:
# (266, 4)

# %%
colors['name'].nunique()
# Out:
# 266

# %% [markdown]
# Oh! there are 266 unique colors of lego blocks present in our data.

# %% [markdown]
# **Challenge**: Find the number of transparent colours where <code>is_trans == 't'</code> versus the number of opaque colours where <code>is_trans == 'f'</code>. See if you can accomplish this in two different ways.

# %%
colors['is_trans'].value_counts()
# Out:
# f    222
# t     44
# Name: is_trans, dtype: int64

# %%
colors.groupby('is_trans')['name'].count()
# Out:
# is_trans
# f    222
# t     44
# Name: name, dtype: int64

# %% [markdown]
# ### Understanding LEGO Themes vs. LEGO Sets

# %% [markdown]
# Walk into a LEGO store and you will see their products organised by theme. Their themes include Star Wars, Batman, Harry Potter and many more.
#
# <img src="https://i.imgur.com/aKcwkSx.png" />

# %% [markdown]
# A lego set is a particular box of LEGO or product. Therefore, a single theme typically has many different sets.
#
# <img src="https://i.imgur.com/whB1olq.png" />

# %% [markdown]
# The <code>sets.csv</code> data contains a list of sets over the years and the number of parts that each of these sets contained.
#
# **Challenge**: Read the sets.csv data and take a look at the first and last couple of rows.

# %%
sets = pd.read_csv('data/sets.csv')

# %%
sets.head()
# Out:
#         set_num                         name  year  theme_id  num_parts  \
# 0  0003977811-1  Ninjago: Book of Adventures  2022       761          1
# 1         001-1                        Gears  1965       756         43
# 2        0011-2            Town Mini-Figures  1979        67         12
# 3        0011-3   Castle 2 for 1 Bonus Offer  1987       199          0
# 4        0012-1           Space Mini-Figures  1979       143         12
#
#                                              img_url
# 0  https://cdn.rebrickable.com/media/sets/0003977...
# 1   https://cdn.rebrickable.com/media/sets/001-1.jpg
# 2  https://cdn.rebrickable.com/media/sets/0011-2.jpg
# 3  https://cdn.rebrickable.com/media/sets/0011-3.jpg
# 4  https://cdn.rebrickable.com/media/sets/0012-1.jpg

# %%
sets.shape
# Out:
# (22335, 6)

# %% [markdown]
# ### In which year were the first LEGO sets released and what were these sets called?

# %%
sets.sort_values('year').iloc[0]
# Out:
# set_num                                                700.3-1
# name                                     Medium Gift Set (ABB)
# year                                                      1949
# theme_id                                                   365
# num_parts                                                  142
# img_url      https://cdn.rebrickable.com/media/sets/700.3-1...
# Name: 13446, dtype: object

# %% [markdown]
# ### How many different sets did LEGO sell in their first year? How many types of LEGO products were on offer in the year the company started?

# %%
sets[sets['year'] == 1949]
# Out:
#        set_num                               name  year  theme_id  num_parts  \
# 13428  700.1-1         Extra-Large Gift Set (ABB)  1949       365        142
# 13441  700.2-1               Large Gift Set (ABB)  1949       365        178
# 13446  700.3-1              Medium Gift Set (ABB)  1949       365        142
# 13452  700.A-1              Small Brick Set (ABB)  1949       371         24
# 13453  700.B-1  Small Doors and Windows Set (ABB)  1949       371         12
#
#                                                  img_url
# 13428  https://cdn.rebrickable.com/media/sets/700.1-1...
# 13441  https://cdn.rebrickable.com/media/sets/700.2-1...
# 13446  https://cdn.rebrickable.com/media/sets/700.3-1...
# 13452  https://cdn.rebrickable.com/media/sets/700.a-1...
# 13453  https://cdn.rebrickable.com/media/sets/700.b-1...

# %% [markdown]
# ### Find the top 5 LEGO sets with the most number of parts.

# %%
sets.sort_values('num_parts', ascending=False).head()
# Out:
#         set_num                           name  year  theme_id  num_parts  \
# 4399    31203-1                      World Map  2021       709      11695
# 410     10307-1                   Eiffel Tower  2022       721      10001
# 21035  BIGBOX-1  The Ultimate Battle for Chima  2015       571       9987
# 396     10294-1                        Titanic  2021       721       9092
# 377     10276-1                      Colosseum  2020       721       9036
#
#                                                  img_url
# 4399   https://cdn.rebrickable.com/media/sets/31203-1...
# 410    https://cdn.rebrickable.com/media/sets/10307-1...
# 21035  https://cdn.rebrickable.com/media/sets/bigbox-...
# 396    https://cdn.rebrickable.com/media/sets/10294-1...
# 377    https://cdn.rebrickable.com/media/sets/10276-1...

# %% [markdown]
# **Challenge**: Use <code>.groupby()</code> and <code>.count()</code> to show the number of LEGO sets released year-on-year. How do the number of sets released in 1955 compare to the number of sets released in 2019?

# %%
sets_by_year = sets.groupby('year')['name'].count().reset_index().rename(columns={"name": "nr_sets"})
sets_by_year.head()
# Out:
#    year  nr_sets
# 0  1949        5
# 1  1950        6
# 2  1953        4
# 3  1954       14
# 4  1955       39

# %%
print(f"Number of sets released in 1949: {sets_by_year[1949]}")
print(f"Number of sets released in 2019: {sets_by_year[2019]}")
# Out:
# Number of sets released in 1949: 5
# Number of sets released in 2019: 1038

# %% [markdown]
# ### Show the number of LEGO releases on a line chart using Matplotlib.
# Note that the .csv file is from early 2024, so to plot the full calendar years, we will have to exclude last this year from our chart.

# %%
plt.figure(figsize=(10, 8))
plt.plot(sets_by_year.year[:-1], sets_by_year.nr_sets[:-1])
plt.ylabel('Number of sets released')
plt.xlabel("Year")
plt.title("Number of sets released per year")
# Out:
# Text(0.5, 1.0, 'Number of sets released per year')

# %% [markdown]
# We also see that while the first 45 years or so, LEGO had some steady growth in its product offering, but it was really in the mid-1990s that the number of sets produced by the company increased dramatically! We also see a brief decline in the early 2000s and a strong recovery around 2005 in the chart.

# %% [markdown]
# ### Aggregate Data with the Python .agg() Function
#
# Let's work out the number of different themes shipped by year. This means we have to count the number of unique theme_ids per calendar year.

# %%
themes_by_year = sets.groupby('year')['theme_id'].agg('nunique')\
.reset_index()

# %%
themes_by_year.rename(columns={'theme_id': "num_of_unique_themes"}, inplace=True)

# %%
themes_by_year.tail()
# Out:
#     year  num_of_unique_themes
# 69  2020                   103
# 70  2021                    98
# 71  2022                    94
# 72  2023                   101
# 73  2024                    55

# %% [markdown]
# ### Plot the number of themes released by year on a line chart. Only include the full calendar years (i.e., exclude 2024).

# %%
plt.plot(themes_by_year.year[:-1], themes_by_year.num_of_unique_themes[:-1])
plt.xlabel('Year')
plt.ylabel('Number of new themes released')
plt.title("Number of new themes released per year")
# Out:
# Text(0.5, 1.0, 'Number of new themes released per year')

# %% [markdown]
# In the chart, we can see that LEGO has pretty consistently added more and more themes until the mid-1990s. From then the number of themes has stagnated for around 10 years or so until the early 2010s.

# %% [markdown]
# ### Line Charts with Two Seperate Axes

# %%
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(sets_by_year.year[:-1], sets_by_year.nr_sets[:-1],'g')
ax2.plot(themes_by_year.year[:-1], themes_by_year.num_of_unique_themes[:-1], 'b')

ax1.set_xlabel('Year')
ax1.set_ylabel('Number of sets', color='green')
ax2.set_ylabel('Number of unique themes', color='blue')
# Out:
# Text(0, 0.5, 'Number of unique themes')

# %% [markdown]
# **Challenge**: Use the <code>.groupby()</code> and <code>.agg()</code> function together to figure out the average number of parts per set. How many parts did the average LEGO set released in 1954 compared to say, 2017?

# %%
avg_parts_per_year = round(sets.groupby('year')['num_parts'].agg('mean'))

# %%
print(f"In 1954, average LEGO set contained: {avg_parts_per_year[1954]} parts")
print(f"In 2017, average LEGO set contained: {avg_parts_per_year[2017]} parts")
# Out:
# In 1954, average LEGO set contained: 8.0 parts
# In 2017, average LEGO set contained: 185.0 parts

# %% [markdown]
# ### Scatter Plots in Matplotlib

# %% [markdown]
# **Challenge**: Has the size and complexity of LEGO sets increased over time based on the number of parts? Plot the average number of parts over time using a Matplotlib scatter plot. See if you can use the [scatter plot documentation](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.scatter.html) before I show you the solution. Do you spot a trend in the chart?

# %%
avg_parts_per_year.reset_index().plot(x='year', y='num_parts', kind='scatter', xlabel='Year', ylabel='Average number of parts', title='Number of Parts per year')
# Out:
# <Axes: title={'center': 'Number of Parts per year'}, xlabel='Year', ylabel='Average number of parts'>

# %% [markdown]
# From the chart, we can definitely make out an upward trend in the size and complexity of the LEGO sets based on the average number of parts. In the 2010s the average set contained around 200 individual pieces, which is roughly double what average LEGO set used to contain in the 1960s.

# %% [markdown]
# ### Number of Sets per LEGO Theme

# %% [markdown]
# LEGO has licensed many hit franchises from Harry Potter to Marvel Super Heros to many others. But which theme has the largest number of individual sets?

# %%
set_theme_count = sets['theme_id'].value_counts().reset_index()
set_theme_count.rename(columns={'index': 'id', 'theme_id': 'set_count'}, inplace=True)
set_theme_count.head()
# Out:
#     id  set_count
# 0  158        902
# 1  503        700
# 2  494        577
# 3  501        550
# 4  435        521

# %% [markdown]
# these results aren't very helpful right. It gives only the theme id but we want its name. now its time to explore themes.csv

# %% [markdown]
# <img src='https://i.imgur.com/Sg4lcjx.png' />

# %% [markdown]
# ### Database Schemas, Foreign Keys and Merging DataFrames
#
# The themes.csv file has the actual theme names. The sets .csv has <code>theme_ids</code> which link to the <code>id</code> column in the themes.csv.

# %% [markdown]
# **Challenge**: Explore the themes.csv. How is it structured? Search for the name 'Star Wars'. How many <code>id</code>s correspond to this name in the themes.csv? Now use these <code>id</code>s and find the corresponding the sets in the sets.csv (Hint: you'll need to look for matches in the <code>theme_id</code> column)

# %%
themes = pd.read_csv('data/themes.csv')

# %%
themes.head()
# Out:
#    id            name  parent_id
# 0   1         Technic        NaN
# 1   3     Competition        1.0
# 2   4  Expert Builder        1.0
# 3  16      RoboRiders        1.0
# 4  17  Speed Slammers        1.0

# %%
themes.shape
# Out:
# (459, 3)

# %%
star_wars = themes[themes['name'] == 'Star Wars']

# %%
sets[sets['theme_id'].isin(star_wars['id'])]
# Out:
#            set_num                             name  year  theme_id  \
# 2163       20006-1                 Clone Turbo Tank  2008       158
# 2174       20007-1          Republic Attack Cruiser  2009       158
# 2187       20009-1                     AT-TE Walker  2009       158
# 2189       20010-1                 Republic Gunship  2009       158
# 2196       20016-1                 Imperial Shuttle  2010       158
# ...            ...                              ...   ...       ...
# 22294         VP-4                Star Wars Co-Pack  2000       158
# 22297         VP-8                Star Wars Co-Pack  2000       158
# 22330      XWING-1              Mini X-Wing Fighter  2019       158
# 22331      XWING-2                X-Wing Trench Run  2019       158
# 22332  YODACHRON-1  Yoda Chronicles Promotional Set  2013       158
#
#        num_parts                                            img_url
# 2163          64  https://cdn.rebrickable.com/media/sets/20006-1...
# ...

# %% [markdown]
# OMG! there are 928 releases of Star Wars LEGO.

# %% [markdown]
# ### Merging (i.e., Combining) DataFrames based on a Key

# %%
merged_df = pd.merge(set_theme_count, themes, on='id')
merged_df.head()
# Out:
#     id  set_count       name  parent_id
# 0  158        902  Star Wars        NaN
# 1  503        700  Key Chain      501.0
# 2  494        577    Friends        NaN
# 3  501        550       Gear        NaN
# 4  435        521    Ninjago        NaN

# %%
plt.bar(merged_df.name[:10], merged_df.set_count[:10])
plt.xticks(rotation=45)
plt.ylabel('Nr of Sets', fontsize=14)
plt.xlabel('Theme Name', fontsize=14)
# Out:
# Text(0.5, 0, 'Theme Name')

# %% [markdown]
# it's interesting that the LEGO company seems to produce so much more these days than just plastic bricks. The 'Gear' category itself is huge and includes everything from bags to pencil cases apparently. Has LEGO strayed from its core business or is it successfully diversifying? That we can't answer from our dataset. I'll leave that one up to a business school case study to decide.
